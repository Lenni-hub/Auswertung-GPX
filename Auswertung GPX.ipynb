# %%
import gpxpy

# GPX Datei öffnen
with open("Heiligenblut_am_Großglockner_Skitour.gpx", "r") as f:
    gpx = gpxpy.parse(f)

# Alle Tracks durchgehen
for track in gpx.tracks:
    for segment in track.segments:
        for point in segment.points:
            print(point.latitude, point.longitude, point.elevation)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import gpxpy
#       3 # GPX Datei öffnen
#       4 with open("Heiligenblut_am_Großglockner_Skitour.gpx", "r") as f:
#
# ModuleNotFoundError: No module named 'gpxpy'
